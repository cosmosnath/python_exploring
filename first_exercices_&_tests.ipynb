# %% [markdown]
# # mes premiers pas en python

# %%
1 + 1
# Out:
# 2

# %%
a=2

# %%
a
# Out:
# 2

# %%
print(a)
# Out:
# 2

# %%
a + 1
a - 5
# Out:
# -3

# %%
print(a)
# Out:
# 2

# %%
a=2

# %%
a = a + 1
a = a - 5

# %%
print(a)
# Out:
# -2

# %%
a += 2

# %%
print(a)
# Out:
# 0

# %%
i = 0
while i < 10:
    print(i)
    i += 3
# Out:
# 0
# 3
# 6
# 9
